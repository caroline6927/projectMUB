# %%
import pandas as pd
import numpy as np
import random
from lib.get_plots import *
from lib.sba_transform import *
from lib.model_pipeline import *

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 7)   # caution: plt namespace may be taken
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/ywang/anaconda/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning:
#
# pylab import has clobbered these variables: ['figure']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = pd.read_csv('demo/fitbituser.csv', parse_dates=['date_time'])
data = filter_na(data)
print(data.describe())
# Out:
#              heart       steps
# count  5950.000000  5950.00000
# mean     71.840504    93.72084
# std      16.009608   228.97116
# min      43.000000     0.00000
# 25%      58.000000     0.00000
# 50%      70.000000     0.00000
# 75%      80.000000    49.00000
# max     156.000000  2306.00000

# %% [markdown]
# # Fill missing data with different methods

# %%
ndata1 = fill_missing(data, method='mean')
ndata2 = fill_missing(data, method='rndminmax')
ndata3 = fill_missing(data, method='rnd50zeromax')
ndata4 = fill_missing(data, method='zero')
ndata5 = fill_missing(data, method='max')
ndatacontrol = fill_missing(data, method='none')

# %%
ndata1 = sba_pipeline(ndata1)
ndata2 = sba_pipeline(ndata2)
ndata3 = sba_pipeline(ndata3)
ndata4 = sba_pipeline(ndata4)
ndata5 = sba_pipeline(ndata5)
ndatacontrol = sba_pipeline(ndatacontrol)

# %% [markdown]
# # Heatmap

# %%
print(ndata1.describe())
ndata1.head(5)

# %%
get_heatmap(ndata1, 'steps', 'ndata1 steps')
get_heatmap(ndata2, 'steps', 'ndata2 steps')
get_heatmap(ndata3, 'steps', 'ndata3 steps')
get_heatmap(ndata4, 'steps', 'ndata4 steps')
get_heatmap(ndata5, 'steps', 'ndata5 steps')
get_heatmap(ndatacontrol, 'steps', 'ndatacontrol steps')

# %% [markdown]
# # Autocorrelation Analysis

# %%
# with sleeping time
get_plot_acf(ndatacontrol.steps, 96*21, 96, title='Autocorrelations of steps in ndatacontrol')
get_plot_acf(ndata1.steps, 96*21, 96, title='Autocorrelations of steps in ndata1')
get_plot_acf(ndata2.steps, 96*21, 96, title='Autocorrelations of steps in ndata2')
get_plot_acf(ndata3.steps, 96*21, 96, title='Autocorrelations of steps in ndata3')
get_plot_acf(ndata4.steps, 96*21, 96, title='Autocorrelations of steps in ndata4')
get_plot_acf(ndata5.steps, 96*21, 96, title='Autocorrelations of steps in ndata5')

# %%
# without sleeping time
get_plot_acf(filter_sleeping_time(ndatacontrol).steps, 68*21, 68, title='Autocorrelations of steps in ndatacontrol')
get_plot_acf(filter_sleeping_time(ndata1).steps, 68*21, 68, title='Autocorrelations of steps in ndata1')
get_plot_acf(filter_sleeping_time(ndata2).steps, 68*21, 68, title='Autocorrelations of steps in ndata2')
get_plot_acf(filter_sleeping_time(ndata3).steps, 68*21, 68, title='Autocorrelations of steps in ndata3')
get_plot_acf(filter_sleeping_time(ndata4).steps, 68*21, 68, title='Autocorrelations of steps in ndata4')
get_plot_acf(filter_sleeping_time(ndata5).steps, 68*21, 68, title='Autocorrelations of steps in ndata5')

# %% [markdown]
# # Get features
#     1) Weekly and daily circadian rhythmicity of physical activity
#     2) Autocorrelation analysis for feature selection

# %%
ndata1_cr, ndata1_cr_features = get_features(ndata1, method='rhythm')
ndata1_ac_s, ndata1_ac_s_features = get_features(ndata1, method='autoco')
ndata1_ac_sh_params = [['steps', 'heart'], 99.8, 0.2, 95]
ndata1_ac_sh, ndata1_ac_sh_features = get_features(ndata1, method='autoco', params=ndata1_ac_sh_params)
# Out:
# the 671 th index has ac of 0.283958
# the 672 th index has ac of 0.211081
# the 1343 th index has ac of 0.230691
# feature indexes are 671, 672, 1343
# index 671 is valid
# index 672 is valid
# index 1343 is valid

# %%
ndata1_cr
# Out:
#                date_time       heart       steps  inactive  time  dayofweek  \
# 0    2016-08-21 00:00:00   74.000000     0.00000        10     0          6
# 1    2016-08-21 00:15:00   71.840504    93.72084       -10    15          6
# 2    2016-08-21 00:30:00   71.840504    93.72084       -10    30          6
# 3    2016-08-21 00:45:00   71.840504    93.72084       -10    45          6
# 4    2016-08-21 01:00:00   71.840504    93.72084       -10    60          6
# 5    2016-08-21 01:15:00   71.840504    93.72084       -10    75          6
# 6    2016-08-21 01:30:00   71.840504    93.72084       -10    90          6
# 7    2016-08-21 01:45:00   71.840504    93.72084       -10   105          6
# 8    2016-08-21 02:00:00   71.840504    93.72084       -10   120          6
# 9    2016-08-21 02:15:00   71.840504    93.72084       -10   135          6
# 10   2016-08-21 02:30:00   71.840504    93.72084       -10   150          6
# 11   2016-08-21 02:45:00   71.840504    93.72084       -10   165          6
# 12   2016-08-21 03:00:00   71.840504    93.72084       -10   180          6
# 13   2016-08-21 03:15:00   71.840504    93.72084       -10   195          6
# 14   2016-08-21 03:30:00   71.840504    93.72084       -10   210          6
# 15   2016-08-21 03:45:00   71.840504    93.72084       -10   225          6
# 16   2016-08-21 04:00:00   71.840504    93.72084       -10   240          6
# 17   2016-08-21 04:15:00   71.840504    93.72084       -10   255          6
# 18   2016-08-21 04:30:00   71.840504    93.72084       -10   270          6
# 19   2016-08-21 04:45:00   71.840504    93.72084       -10   285          6
# 20   2016-08-21 05:00:00   71.840504    93.72084       -10   300          6
# 21   2016-08-21 05:15:00   71.840504    93.72084       -10   315          6
# 22   2016-08-21 05:30:00   71.840504    93.72084       -10   330          6
# 23   2016-08-21 05:45:00   71.840504    93.72084       -10   345          6
# 24   2016-08-21 06:00:00   71.840504    93.72084       -10   360          6
# 25   2016-08-21 06:15:00   71.840504    93.72084       -10   375          6
# 26   2016-08-21 06:30:00   71.840504    93.72084       -10   390          6
# 27   2016-08-21 06:45:00   71.840504    93.72084       -10   405          6
# 28   2016-08-21 07:00:00   71.840504    93.72084       -10   420          6
# 29   2016-08-21 07:15:00   71.840504    93.72084       -10   435          6
# ...                  ...         ...         ...       ...   ...        ...
# 6498 2016-10-27 16:30:00   63.000000     0.00000        10   990          3
# 6499 2016-10-27 16:45:00   63.000000     0.00000        10  1005          3
# 6500 2016-10-27 17:00:00   67.000000     0.00000        10  1020          3
# 6501 2016-10-27 17:15:00   66.000000     0.00000        10  1035          3
# 6502 2016-10-27 17:30:00   65.000000     0.00000        10  1050          3
# 6503 2016-10-27 17:45:00   79.000000   209.00000       -10  1065          3
# 6504 2016-10-27 18:00:00   82.000000   190.00000       -10  1080          3
# 6505 2016-10-27 18:15:00   87.000000   280.00000       -10  1095          3
# 6506 2016-10-27 18:30:00   93.000000   506.00000       -10  1110          3
# 6507 2016-10-27 18:45:00   88.000000   339.00000       -10  1125          3
# 6508 2016-10-27 19:00:00   70.000000     0.00000        10  1140          3
# 6509 2016-10-27 19:15:00   65.000000     0.00000        10  1155          3
# 6510 2016-10-27 19:30:00   65.000000     0.00000        10  1170          3
# 6511 2016-10-27 19:45:00   64.000000    41.00000       -10  1185          3
# 6512 2016-10-27 20:00:00   80.000000   367.00000       -10  1200          3
# 6513 2016-10-27 20:15:00   70.000000    91.00000       -10  1215          3
# 6514 2016-10-27 20:30:00   69.000000     0.00000        10  1230          3
# 6515 2016-10-27 20:45:00   79.000000   198.00000       -10  1245          3
# 6516 2016-10-27 21:00:00  130.000000  1708.00000       -10  1260          3
# 6517 2016-10-27 21:15:00  138.000000  1951.00000       -10  1275          3
# 6518 2016-10-27 21:30:00  149.000000  1792.00000       -10  1290          3
# 6519 2016-10-27 21:45:00  106.000000   738.00000       -10  1305          3
# 6520 2016-10-27 22:00:00   99.000000     0.00000        10  1320          3
# 6521 2016-10-27 22:15:00  115.000000     0.00000        10  1335          3
# 6522 2016-10-27 22:30:00  102.000000     0.00000        10  1350          3
# 6523 2016-10-27 22:45:00   71.840504    93.72084       -10  1365          3
# 6524 2016-10-27 23:00:00   76.000000     0.00000        10  1380          3
# 6525 2016-10-27 23:15:00   66.000000     0.00000        10  1395          3
# 6526 2016-10-27 23:30:00   67.000000     0.00000        10  1410          3
# 6527 2016-10-27 23:45:00   61.000000     0.00000        10  1425          3
#
#       timeofweek
# 0           8634
# 1           8649
# 2           8664
# 3           8679
# 4           8694
# 5           8709
# 6           8724
# 7           8739
# 8           8754
# 9           8769
# 10          8784
# 11          8799
# 12          8814
# 13          8829
# 14          8844
# 15          8859
# 16          8874
# 17          8889
# 18          8904
# 19          8919
# 20          8934
# 21          8949
# 22          8964
# 23          8979
# 24          8994
# 25          9009
# 26          9024
# 27          9039
# 28          9054
# 29          9069
# ...          ...
# 6498        5307
# 6499        5322
# 6500        5337
# 6501        5352
# 6502        5367
# 6503        5382
# 6504        5397
# 6505        5412
# 6506        5427
# 6507        5442
# 6508        5457
# 6509        5472
# 6510        5487
# 6511        5502
# 6512        5517
# 6513        5532
# 6514        5547
# 6515        5562
# 6516        5577
# 6517        5592
# 6518        5607
# 6519        5622
# 6520        5637
# 6521        5652
# 6522        5667
# 6523        5682
# 6524        5697
# 6525        5712
# 6526        5727
# 6527        5742
#
# [6528 rows x 7 columns]

# %%
ndata1_ac
# Out:
#                date_time       heart       steps  inactive  \
# 0    2016-09-03 23:45:00   65.000000     0.00000        10
# 1    2016-09-04 00:00:00   65.000000     0.00000        10
# 2    2016-09-04 00:15:00   64.000000     0.00000        10
# 3    2016-09-04 00:30:00   88.000000   284.00000       -10
# 4    2016-09-04 00:45:00   73.000000    52.00000       -10
# 5    2016-09-04 01:00:00   63.000000     0.00000        10
# 6    2016-09-04 01:15:00   69.000000     0.00000        10
# 7    2016-09-04 01:30:00   67.000000    15.00000       -10
# 8    2016-09-04 01:45:00   62.000000     0.00000        10
# 9    2016-09-04 02:00:00   57.000000     0.00000        10
# 10   2016-09-04 02:15:00   56.000000     0.00000        10
# 11   2016-09-04 02:30:00   56.000000     0.00000        10
# 12   2016-09-04 02:45:00   57.000000     8.00000       -10
# 13   2016-09-04 03:00:00   59.000000     0.00000        10
# 14   2016-09-04 03:15:00   57.000000    10.00000       -10
# 15   2016-09-04 03:30:00   51.000000     0.00000        10
# 16   2016-09-04 03:45:00   49.000000     0.00000        10
# 17   2016-09-04 04:00:00   49.000000     0.00000        10
# 18   2016-09-04 04:15:00   51.000000     0.00000        10
# 19   2016-09-04 04:30:00   52.000000     0.00000        10
# 20   2016-09-04 04:45:00   53.000000     0.00000        10
# 21   2016-09-04 05:00:00   57.000000     0.00000        10
# 22   2016-09-04 05:15:00   54.000000     0.00000        10
# 23   2016-09-04 05:30:00   51.000000     0.00000        10
# 24   2016-09-04 05:45:00   52.000000     0.00000        10
# 25   2016-09-04 06:00:00   53.000000     0.00000        10
# 26   2016-09-04 06:15:00   51.000000     0.00000        10
# 27   2016-09-04 06:30:00   53.000000     0.00000        10
# 28   2016-09-04 06:45:00   54.000000     0.00000        10
# 29   2016-09-04 07:00:00   57.000000     0.00000        10
# ...                  ...         ...         ...       ...
# 5155 2016-10-27 16:30:00   63.000000     0.00000        10
# 5156 2016-10-27 16:45:00   63.000000     0.00000        10
# 5157 2016-10-27 17:00:00   67.000000     0.00000        10
# 5158 2016-10-27 17:15:00   66.000000     0.00000        10
# 5159 2016-10-27 17:30:00   65.000000     0.00000        10
# 5160 2016-10-27 17:45:00   79.000000   209.00000       -10
# 5161 2016-10-27 18:00:00   82.000000   190.00000       -10
# 5162 2016-10-27 18:15:00   87.000000   280.00000       -10
# 5163 2016-10-27 18:30:00   93.000000   506.00000       -10
# 5164 2016-10-27 18:45:00   88.000000   339.00000       -10
# 5165 2016-10-27 19:00:00   70.000000     0.00000        10
# 5166 2016-10-27 19:15:00   65.000000     0.00000        10
# 5167 2016-10-27 19:30:00   65.000000     0.00000        10
# 5168 2016-10-27 19:45:00   64.000000    41.00000       -10
# 5169 2016-10-27 20:00:00   80.000000   367.00000       -10
# 5170 2016-10-27 20:15:00   70.000000    91.00000       -10
# 5171 2016-10-27 20:30:00   69.000000     0.00000        10
# 5172 2016-10-27 20:45:00   79.000000   198.00000       -10
# 5173 2016-10-27 21:00:00  130.000000  1708.00000       -10
# 5174 2016-10-27 21:15:00  138.000000  1951.00000       -10
# 5175 2016-10-27 21:30:00  149.000000  1792.00000       -10
# 5176 2016-10-27 21:45:00  106.000000   738.00000       -10
# 5177 2016-10-27 22:00:00   99.000000     0.00000        10
# 5178 2016-10-27 22:15:00  115.000000     0.00000        10
# 5179 2016-10-27 22:30:00  102.000000     0.00000        10
# 5180 2016-10-27 22:45:00   71.840504    93.72084       -10
# 5181 2016-10-27 23:00:00   76.000000     0.00000        10
# 5182 2016-10-27 23:15:00   66.000000     0.00000        10
# 5183 2016-10-27 23:30:00   67.000000     0.00000        10
# 5184 2016-10-27 23:45:00   61.000000     0.00000        10
#
#       stepsfeature_index671  stepsfeature_index672  stepsfeature_index1343
# 0                 166.00000               93.72084                 0.00000
# 1                   1.00000              166.00000                93.72084
# 2                   0.00000                1.00000                93.72084
# 3                   0.00000                0.00000                93.72084
# 4                   0.00000                0.00000                93.72084
# 5                   0.00000                0.00000                93.72084
# 6                   0.00000                0.00000                93.72084
# 7                  15.00000                0.00000                93.72084
# 8                  16.00000               15.00000                93.72084
# 9                  44.00000               16.00000                93.72084
# 10                 26.00000               44.00000                93.72084
# 11                  0.00000               26.00000                93.72084
# 12                  0.00000                0.00000                93.72084
# 13                  0.00000                0.00000                93.72084
# 14                  0.00000                0.00000                93.72084
# 15                  0.00000                0.00000                93.72084
# 16                 54.00000                0.00000                93.72084
# 17                  0.00000               54.00000                93.72084
# 18                  0.00000                0.00000                93.72084
# 19                  0.00000                0.00000                93.72084
# 20                  0.00000                0.00000                93.72084
# 21                  0.00000                0.00000                93.72084
# 22                  0.00000                0.00000                93.72084
# 23                  0.00000                0.00000                93.72084
# 24                  0.00000                0.00000                93.72084
# 25                  0.00000                0.00000                93.72084
# 26                  0.00000                0.00000                93.72084
# 27                  0.00000                0.00000                93.72084
# 28                  0.00000                0.00000                93.72084
# 29                  0.00000                0.00000                93.72084
# ...                     ...                    ...                     ...
# 5155                5.00000                0.00000                 0.00000
# 5156               66.00000                5.00000                 0.00000
# 5157                0.00000               66.00000                69.00000
# 5158                0.00000                0.00000                47.00000
# 5159                6.00000                0.00000                 0.00000
# 5160                0.00000                6.00000                 0.00000
# 5161                0.00000                0.00000                11.00000
# 5162                0.00000                0.00000                 0.00000
# 5163                0.00000                0.00000                 0.00000
# 5164                0.00000                0.00000                 0.00000
# 5165                0.00000                0.00000                 0.00000
# 5166                0.00000                0.00000                39.00000
# 5167                0.00000                0.00000                 0.00000
# 5168               45.00000                0.00000                 0.00000
# 5169                0.00000               45.00000                 9.00000
# 5170               48.00000                0.00000                 0.00000
# 5171               93.72084               48.00000                 0.00000
# 5172               93.72084               93.72084                 0.00000
# 5173               93.72084               93.72084                 0.00000
# 5174               93.72084               93.72084                 0.00000
# 5175               93.72084               93.72084                12.00000
# 5176               93.72084               93.72084                 0.00000
# 5177              174.00000               93.72084                26.00000
# 5178               88.00000              174.00000                93.72084
# 5179               40.00000               88.00000                93.72084
# 5180                0.00000               40.00000                93.72084
# 5181                0.00000                0.00000                93.72084
# 5182              256.00000                0.00000                93.72084
# 5183                0.00000              256.00000                93.72084
# 5184                0.00000                0.00000                93.72084
#
# [5185 rows x 7 columns]

# %% [markdown]
# # Decision Tree
# 1. Use rhythm features
# 2. Use autoco features
#     - 1) steps
#     - 2) steps, heart

# %%
from lib.dt_model import *

# %%
ndata1_cr_model, ndata1_cr_model_features = get_dt_model(ndata1_cr, ndata1_cr_features, 'inactive', optimized=True)
ndata1_ac_model, ndata1_ac_model_features = get_dt_model(ndata1_ac, ndata1_ac_features, 'inactive', optimized=True)
ndata1_ac_model, ndata1_ac_model_features = get_dt_model(ndata1_ac, ndata1_ac_features, 'inactive', optimized=True)
# Out:
# accuracy based on training data is 0.652727
# accuracy based on training data is 0.551011
# accuracy based on training data is 0.696844
# accuracy based on training data is 0.694547
# accuracy based on training data is 0.696538
# accuracy based on training data is 0.696844
# accuracy based on training data is 0.696538
# best features are: 'timeofweek'
# accuracy based on training data is 0.696844

# %%
ndata1_ac_model, ndata1_ac_model_features = get_dt_model(ndata1_ac, ndata1_ac_features, 'inactive', optimized=True)
# Out:
# accuracy based on training data is 0.629894
# accuracy based on training data is 0.629894
# accuracy based on training data is 0.630665
# accuracy based on training data is 0.672710
# accuracy based on training data is 0.687175
# accuracy based on training data is 0.692960
# accuracy based on training data is 0.717261
# best features are: 'stepsfeature_index671', 'stepsfeature_index672', 'stepsfeature_index1343'
# accuracy based on training data is 0.717261

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'), index=['Utah', 'Ohio', 'Texas', 'Oregon']); frame
foo = set(['a', 'b','b', 'c', 'd', 'e'])
print(random.sample(foo,2))
type(set([x for x in range(7)])[0])
frame.reset_index(inplace=True)
frame.loc[[2,3], :]
