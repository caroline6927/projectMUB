# %%
import pandas as pd
import numpy as np
import random
from lib.get_plots import *
from lib.sba_transform import *
from lib.model_pipeline import *
from lib.dt_model import *
from lib.demo_model_pipeline import *

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 7)   # caution: plt namespace may be taken
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/ywang/anaconda/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning:
#
# pylab import has clobbered these variables: ['figure', 'random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
data = pd.read_csv('demo/fitbituser.csv', parse_dates=['date_time'])
data = filter_na(data)
print(data.describe())
# Out:
#              heart       steps
# count  5950.000000  5950.00000
# mean     71.840504    93.72084
# std      16.009608   228.97116
# min      43.000000     0.00000
# 25%      58.000000     0.00000
# 50%      70.000000     0.00000
# 75%      80.000000    49.00000
# max     156.000000  2306.00000

# %% [markdown]
# # Fill missing data with different methods

# %%
ndata1 = fill_missing(data, method='mean')
ndata2 = fill_missing(data, method='rndminmax')
ndata3 = fill_missing(data, method='rnd50zeromax')
ndata4 = fill_missing(data, method='zero')
ndata5 = fill_missing(data, method='max')
ndatacontrol = fill_missing(data, method='none')

# %%
ndata1 = sba_pipeline(ndata1)
ndata2 = sba_pipeline(ndata2)
ndata3 = sba_pipeline(ndata3)
ndata4 = sba_pipeline(ndata4)
ndata5 = sba_pipeline(ndata5)
ndatacontrol = sba_pipeline(ndatacontrol)

# %% [markdown]
# # Heatmap

# %%
print(ndata1.describe())
ndata1.head(5)

# %%
get_heatmap(ndata1, 'steps', 'ndata1 steps')
get_heatmap(ndata2, 'steps', 'ndata2 steps')
get_heatmap(ndata3, 'steps', 'ndata3 steps')
get_heatmap(ndata4, 'steps', 'ndata4 steps')
get_heatmap(ndata5, 'steps', 'ndata5 steps')
get_heatmap(ndatacontrol, 'steps', 'ndatacontrol steps')

# %% [markdown]
# # Autocorrelation Analysis

# %%
# with sleeping time
get_plot_acf(ndatacontrol.steps, 96*21, 96, title='Autocorrelations of steps in ndatacontrol')
get_plot_acf(ndata1.steps, 96*21, 96, title='Autocorrelations of steps in ndata1')
get_plot_acf(ndata2.steps, 96*21, 96, title='Autocorrelations of steps in ndata2')
get_plot_acf(ndata3.steps, 96*21, 96, title='Autocorrelations of steps in ndata3')
get_plot_acf(ndata4.steps, 96*21, 96, title='Autocorrelations of steps in ndata4')
get_plot_acf(ndata5.steps, 96*21, 96, title='Autocorrelations of steps in ndata5')

# %%
# without sleeping time
get_plot_acf(filter_sleeping_time(ndatacontrol).steps, 68*21, 68, title='Autocorrelations of steps in ndatacontrol')
get_plot_acf(filter_sleeping_time(ndata1).steps, 68*21, 68, title='Autocorrelations of steps in ndata1')
get_plot_acf(filter_sleeping_time(ndata2).steps, 68*21, 68, title='Autocorrelations of steps in ndata2')
get_plot_acf(filter_sleeping_time(ndata3).steps, 68*21, 68, title='Autocorrelations of steps in ndata3')
get_plot_acf(filter_sleeping_time(ndata4).steps, 68*21, 68, title='Autocorrelations of steps in ndata4')
get_plot_acf(filter_sleeping_time(ndata5).steps, 68*21, 68, title='Autocorrelations of steps in ndata5')

# %% [markdown]
# # Get features
#     1) Weekly and daily circadian rhythmicity of physical activity
#     2) Autocorrelation analysis for feature selection

# %%
# 1. circadian rhythmicity features: time, time of week, day of week
ndata1_cr, ndata1_cr_features = get_features(ndata1, method='rhythm')
# 2. autocorrelated parameters: steps
ndata1_ac_s, ndata1_ac_s_features = get_features(ndata1, method='autoco')
# 3. autocorrelated parameters: steps and heart
ndata1_ac_sh_params = ['steps', 'heart']
ndata1_ac_sh, ndata1_ac_sh_features_subset = get_features(ndata1, method='autoco', params=ndata1_ac_sh_params)
ndata1_ac_sh_features = [item for sublist in ndata1_ac_sh_features_subset for item in sublist]
# 4. circadian rhythmicity features + autocorrelated parameters: time, time of week, day of week, steps, heart
ndata1_ac_shr, ndata1_ac_shr_features_subset = get_features(ndata1_ac_sh, method='rhythm')
ndata1_ac_shr_features = ndata1_ac_shr_features_subset + ndata1_ac_sh_features
# Out:
# the 671 th index has ac of 0.283958
# the 672 th index has ac of 0.211081
# the 1343 th index has ac of 0.230691
# feature indexes are 671, 672, 1343
# index 671 is valid
# index 672 is valid
# index 1343 is valid
# the 671 th index has ac of 0.283958
# the 672 th index has ac of 0.211081
# the 1343 th index has ac of 0.230691
# feature indexes are 671, 672, 1343
# index 671 is valid
# index 672 is valid
# index 1343 is valid
# the 671 th index has ac of 0.283958
# the 672 th index has ac of 0.211081
# the 1343 th index has ac of 0.230691
# feature indexes are 671, 672, 1343
# index 671 is valid
# index 672 is valid
# index 1343 is valid

# %%
ndata1_ac_shr.head()
# Out:
#             date_time  heart  steps  inactive  stepsfeature_index671  \
# 0 2016-09-03 23:45:00   65.0    0.0        10                  166.0
# 1 2016-09-04 00:00:00   65.0    0.0        10                    1.0
# 2 2016-09-04 00:15:00   64.0    0.0        10                    0.0
# 3 2016-09-04 00:30:00   88.0  284.0       -10                    0.0
# 4 2016-09-04 00:45:00   73.0   52.0       -10                    0.0
#
#    stepsfeature_index672  stepsfeature_index1343  heartfeature_index671  \
# 0               93.72084                 0.00000                  115.0
# 1              166.00000                93.72084                   73.0
# 2                1.00000                93.72084                   68.0
# 3                0.00000                93.72084                   70.0
# 4                0.00000                93.72084                   64.0
#
#    heartfeature_index672  heartfeature_index1343  time  dayofweek  timeofweek
# 0              71.840504               74.000000  1425          5        8620
# 1             115.000000               71.840504     0          6        8634
# 2              73.000000               71.840504    15          6        8649
# 3              68.000000               71.840504    30          6        8664
# 4              70.000000               71.840504    45          6        8679

# %% [markdown]
# # Machine Learning Models
# 1. Use rhythm features
# 2. Use autoco features
#     - 1) steps
#     - 2) steps, heart

# %%
# get train and test
ndata1_ac_shr_train, ndata1_ac_shr_test = get_train_test(ndata1_ac_shr, split=0.8)

# %%
# Decision Tree 
# 80.59% 58.92%
# prediction score on test data is 0.589200
# false positive rate is 0.207329
# false negative rate is 0.203472
ndata1_ac_shr_model, ndata1_ac_shr_model_features = get_dt_model(ndata1_ac_shr_train, ndata1_ac_shr_features, 
                                                             'inactive', optimized=True)
ndata1_ac_shr_model_predicted, ndata1_ac_shr_model_accuracy = get_prediction(ndata1_ac_shr_test, 
                                                                             ndata1_ac_shr_model, 
                                                                             'inactive', 
                                                                             ndata1_ac_shr_model_features)
get_model_accuracy(ndata1_ac_shr_model_predicted, ndata1_ac_shr_test['inactive'])
# Out:
# accuracy based on training data is 0.656461
# accuracy based on training data is 0.564127
# accuracy based on training data is 0.716731
# accuracy based on training data is 0.626567
# accuracy based on training data is 0.626808
# accuracy based on training data is 0.630665
# accuracy based on training data is 0.624156
# accuracy based on training data is 0.630183
# accuracy based on training data is 0.629942
# accuracy based on training data is 0.711427
# accuracy based on training data is 0.717936
# accuracy based on training data is 0.703230
# accuracy based on training data is 0.715284
# accuracy based on training data is 0.721311
# accuracy based on training data is 0.720588
# accuracy based on training data is 0.722758
# accuracy based on training data is 0.729026
# accuracy based on training data is 0.716731
# accuracy based on training data is 0.662006
# accuracy based on training data is 0.659836
# accuracy based on training data is 0.670685
# accuracy based on training data is 0.679605
# accuracy based on training data is 0.678399
# accuracy based on training data is 0.687319
# accuracy based on training data is 0.758679
# accuracy based on training data is 0.759161
# accuracy based on training data is 0.765670
# accuracy based on training data is 0.764947
# accuracy based on training data is 0.763742
# accuracy based on training data is 0.762536
# accuracy based on training data is 0.664658
# accuracy based on training data is 0.689007
# accuracy based on training data is 0.674542
# accuracy based on training data is 0.684908
# accuracy based on training data is 0.701061
# accuracy based on training data is 0.692623
# accuracy based on training data is 0.675024
# accuracy based on training data is 0.677194
# accuracy based on training data is 0.695757
# accuracy based on training data is 0.701061
# accuracy based on training data is 0.694069
# accuracy based on training data is 0.687560
# accuracy based on training data is 0.683462
# accuracy based on training data is 0.707570
# accuracy based on training data is 0.711186
# accuracy based on training data is 0.717936
# accuracy based on training data is 0.756991
# accuracy based on training data is 0.748795
# accuracy based on training data is 0.756268
# accuracy based on training data is 0.761090
# accuracy based on training data is 0.758920
# accuracy based on training data is 0.756027
# accuracy based on training data is 0.760608
# accuracy based on training data is 0.759161
# accuracy based on training data is 0.763018
# accuracy based on training data is 0.766393
# accuracy based on training data is 0.772420
# accuracy based on training data is 0.767358
# accuracy based on training data is 0.741803
# accuracy based on training data is 0.750964
# accuracy based on training data is 0.740839
# accuracy based on training data is 0.748795
# accuracy based on training data is 0.758679
# accuracy based on training data is 0.754339
# accuracy based on training data is 0.742768
# accuracy based on training data is 0.745178
# accuracy based on training data is 0.756027
# accuracy based on training data is 0.753134
# accuracy based on training data is 0.751688
# accuracy based on training data is 0.760366
# accuracy based on training data is 0.749277
# accuracy based on training data is 0.758197
# accuracy based on training data is 0.745661
# accuracy based on training data is 0.758679
# accuracy based on training data is 0.759161
# accuracy based on training data is 0.765670
# accuracy based on training data is 0.765188
# accuracy based on training data is 0.763983
# accuracy based on training data is 0.762536
# accuracy based on training data is 0.696962
# accuracy based on training data is 0.703472
# accuracy based on training data is 0.728785
# accuracy based on training data is 0.730231
# accuracy based on training data is 0.735776
# accuracy based on training data is 0.710945
# accuracy based on training data is 0.723722
# accuracy based on training data is 0.720106
# accuracy based on training data is 0.730714
# accuracy based on training data is 0.723240
# accuracy based on training data is 0.724928
# accuracy based on training data is 0.729508
# accuracy based on training data is 0.722999
# accuracy based on training data is 0.736258
# accuracy based on training data is 0.736017
# accuracy based on training data is 0.770974
# accuracy based on training data is 0.778930
# accuracy based on training data is 0.775072
# accuracy based on training data is 0.771456
# accuracy based on training data is 0.779653
# accuracy based on training data is 0.774108
# accuracy based on training data is 0.776760
# accuracy based on training data is 0.773867
# accuracy based on training data is 0.777965
# accuracy based on training data is 0.776278
# accuracy based on training data is 0.773385
# accuracy based on training data is 0.773867
# accuracy based on training data is 0.777001
# accuracy based on training data is 0.772903
# accuracy based on training data is 0.775313
# accuracy based on training data is 0.717454
# accuracy based on training data is 0.702266
# accuracy based on training data is 0.711186
# accuracy based on training data is 0.723722
# accuracy based on training data is 0.723481
# accuracy based on training data is 0.736741
# accuracy based on training data is 0.724204
# accuracy based on training data is 0.715284
# accuracy based on training data is 0.732160
# accuracy based on training data is 0.739634
# accuracy based on training data is 0.723240
# accuracy based on training data is 0.724204
# accuracy based on training data is 0.729990
# accuracy based on training data is 0.716008
# accuracy based on training data is 0.740357
# accuracy based on training data is 0.733124
# accuracy based on training data is 0.736500
# accuracy based on training data is 0.736017
# accuracy based on training data is 0.736017
# accuracy based on training data is 0.740116
# accuracy based on training data is 0.760608
# accuracy based on training data is 0.759161
# accuracy based on training data is 0.763259
# accuracy based on training data is 0.766393
# accuracy based on training data is 0.772420
# accuracy based on training data is 0.767358
# accuracy based on training data is 0.763259
# accuracy based on training data is 0.766635
# accuracy based on training data is 0.773626
# accuracy based on training data is 0.772179
# accuracy based on training data is 0.770733
# accuracy based on training data is 0.767840
# accuracy based on training data is 0.768563
# accuracy based on training data is 0.776037
# accuracy based on training data is 0.774831
# accuracy based on training data is 0.773626
# accuracy based on training data is 0.775072
# accuracy based on training data is 0.767358
# accuracy based on training data is 0.776760
# accuracy based on training data is 0.779412
# accuracy based on training data is 0.776519
# accuracy based on training data is 0.778447
# accuracy based on training data is 0.775796
# accuracy based on training data is 0.772662
# accuracy based on training data is 0.782787
# accuracy based on training data is 0.785680
# accuracy based on training data is 0.780617
# accuracy based on training data is 0.771938
# accuracy based on training data is 0.780617
# accuracy based on training data is 0.783510
# accuracy based on training data is 0.782305
# accuracy based on training data is 0.781340
# accuracy based on training data is 0.785680
# accuracy based on training data is 0.777965
# accuracy based on training data is 0.786162
# accuracy based on training data is 0.780135
# accuracy based on training data is 0.764224
# accuracy based on training data is 0.754339
# accuracy based on training data is 0.767599
# accuracy based on training data is 0.769286
# accuracy based on training data is 0.764224
# accuracy based on training data is 0.768322
# accuracy based on training data is 0.770492
# accuracy based on training data is 0.755786
# accuracy based on training data is 0.761813
# accuracy based on training data is 0.767840
# accuracy based on training data is 0.763500
# accuracy based on training data is 0.768322
# accuracy based on training data is 0.770974
# accuracy based on training data is 0.761813
# accuracy based on training data is 0.767840
# accuracy based on training data is 0.768322
# accuracy based on training data is 0.768322
# accuracy based on training data is 0.769769
# accuracy based on training data is 0.765911
# accuracy based on training data is 0.763983
# accuracy based on training data is 0.770974
# accuracy based on training data is 0.779653
# accuracy based on training data is 0.775072
# accuracy based on training data is 0.771215
# accuracy based on training data is 0.779653
# accuracy based on training data is 0.772903
# accuracy based on training data is 0.777001
# accuracy based on training data is 0.772662
# accuracy based on training data is 0.777724
# accuracy based on training data is 0.776760
# accuracy based on training data is 0.773385
# accuracy based on training data is 0.774349
# accuracy based on training data is 0.777001
# accuracy based on training data is 0.772903
# accuracy based on training data is 0.775313
# accuracy based on training data is 0.731919
# accuracy based on training data is 0.740116
# accuracy based on training data is 0.743250
# accuracy based on training data is 0.752170
# accuracy based on training data is 0.748795
# accuracy based on training data is 0.743009
# accuracy based on training data is 0.748554
# accuracy based on training data is 0.745178
# accuracy based on training data is 0.762777
# accuracy based on training data is 0.755304
# accuracy based on training data is 0.750241
# accuracy based on training data is 0.745661
# accuracy based on training data is 0.754822
# accuracy based on training data is 0.740598
# accuracy based on training data is 0.756991
# accuracy based on training data is 0.760125
# accuracy based on training data is 0.755063
# accuracy based on training data is 0.760849
# accuracy based on training data is 0.762054
# accuracy based on training data is 0.764465
# accuracy based on training data is 0.778206
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.778447
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.783269
# accuracy based on training data is 0.779653
# accuracy based on training data is 0.783510
# accuracy based on training data is 0.776037
# accuracy based on training data is 0.784716
# accuracy based on training data is 0.778206
# accuracy based on training data is 0.782305
# accuracy based on training data is 0.781340
# accuracy based on training data is 0.781340
# accuracy based on training data is 0.774108
# accuracy based on training data is 0.785198
# accuracy based on training data is 0.781823
# accuracy based on training data is 0.788814
# accuracy based on training data is 0.776760
# accuracy based on training data is 0.779412
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.741080
# accuracy based on training data is 0.739875
# accuracy based on training data is 0.748312
# accuracy based on training data is 0.734089
# accuracy based on training data is 0.751205
# accuracy based on training data is 0.751446
# accuracy based on training data is 0.746866
# accuracy based on training data is 0.753134
# accuracy based on training data is 0.753134
# accuracy based on training data is 0.756750
# accuracy based on training data is 0.747830
# accuracy based on training data is 0.751446
# accuracy based on training data is 0.750723
# accuracy based on training data is 0.751205
# accuracy based on training data is 0.754581
# accuracy based on training data is 0.778206
# accuracy based on training data is 0.776278
# accuracy based on training data is 0.773867
# accuracy based on training data is 0.781823
# accuracy based on training data is 0.785680
# accuracy based on training data is 0.778206
# accuracy based on training data is 0.770010
# accuracy based on training data is 0.779894
# accuracy based on training data is 0.782787
# accuracy based on training data is 0.782546
# accuracy based on training data is 0.780858
# accuracy based on training data is 0.784716
# accuracy based on training data is 0.777965
# accuracy based on training data is 0.786162
# accuracy based on training data is 0.780135
# accuracy based on training data is 0.773867
# accuracy based on training data is 0.776760
# accuracy based on training data is 0.774590
# accuracy based on training data is 0.780376
# accuracy based on training data is 0.776278
# accuracy based on training data is 0.775072
# accuracy based on training data is 0.770974
# accuracy based on training data is 0.784474
# accuracy based on training data is 0.779412
# accuracy based on training data is 0.779894
# accuracy based on training data is 0.771215
# accuracy based on training data is 0.780376
# accuracy based on training data is 0.780617
# accuracy based on training data is 0.777724
# accuracy based on training data is 0.780376
# accuracy based on training data is 0.783028
# accuracy based on training data is 0.786162
# accuracy based on training data is 0.781340
# accuracy based on training data is 0.788332
# accuracy based on training data is 0.789537
# accuracy based on training data is 0.782546
# accuracy based on training data is 0.781581
# accuracy based on training data is 0.785921
# accuracy based on training data is 0.789296
# accuracy based on training data is 0.784716
# accuracy based on training data is 0.788573
# accuracy based on training data is 0.793153
# accuracy based on training data is 0.789778
# accuracy based on training data is 0.790743
# accuracy based on training data is 0.793635
# accuracy based on training data is 0.781823
# accuracy based on training data is 0.785198
# accuracy based on training data is 0.786162
# accuracy based on training data is 0.791707
# accuracy based on training data is 0.794600
# accuracy based on training data is 0.790501
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.791948
# accuracy based on training data is 0.793153
# accuracy based on training data is 0.797252
# accuracy based on training data is 0.766635
# accuracy based on training data is 0.775072
# accuracy based on training data is 0.774831
# accuracy based on training data is 0.768804
# accuracy based on training data is 0.777965
# accuracy based on training data is 0.777001
# accuracy based on training data is 0.771456
# accuracy based on training data is 0.770251
# accuracy based on training data is 0.773385
# accuracy based on training data is 0.772179
# accuracy based on training data is 0.772662
# accuracy based on training data is 0.774590
# accuracy based on training data is 0.773626
# accuracy based on training data is 0.769769
# accuracy based on training data is 0.777242
# accuracy based on training data is 0.776760
# accuracy based on training data is 0.787850
# accuracy based on training data is 0.778930
# accuracy based on training data is 0.788332
# accuracy based on training data is 0.783510
# accuracy based on training data is 0.779653
# accuracy based on training data is 0.783028
# accuracy based on training data is 0.776037
# accuracy based on training data is 0.784474
# accuracy based on training data is 0.776278
# accuracy based on training data is 0.782787
# accuracy based on training data is 0.781340
# accuracy based on training data is 0.780135
# accuracy based on training data is 0.774349
# accuracy based on training data is 0.785198
# accuracy based on training data is 0.781823
# accuracy based on training data is 0.789055
# accuracy based on training data is 0.776760
# accuracy based on training data is 0.778206
# accuracy based on training data is 0.786403
# accuracy based on training data is 0.760849
# accuracy based on training data is 0.760366
# accuracy based on training data is 0.762295
# accuracy based on training data is 0.752411
# accuracy based on training data is 0.768804
# accuracy based on training data is 0.771697
# accuracy based on training data is 0.757956
# accuracy based on training data is 0.770251
# accuracy based on training data is 0.762536
# accuracy based on training data is 0.773626
# accuracy based on training data is 0.759884
# accuracy based on training data is 0.773626
# accuracy based on training data is 0.772420
# accuracy based on training data is 0.766635
# accuracy based on training data is 0.775796
# accuracy based on training data is 0.782064
# accuracy based on training data is 0.784957
# accuracy based on training data is 0.790260
# accuracy based on training data is 0.783028
# accuracy based on training data is 0.786403
# accuracy based on training data is 0.783992
# accuracy based on training data is 0.788332
# accuracy based on training data is 0.783992
# accuracy based on training data is 0.780858
# accuracy based on training data is 0.786403
# accuracy based on training data is 0.785439
# accuracy based on training data is 0.782305
# accuracy based on training data is 0.783992
# accuracy based on training data is 0.790743
# accuracy based on training data is 0.787850
# accuracy based on training data is 0.757232
# accuracy based on training data is 0.757473
# accuracy based on training data is 0.766635
# accuracy based on training data is 0.765911
# accuracy based on training data is 0.764465
# accuracy based on training data is 0.762777
# accuracy based on training data is 0.782787
# accuracy based on training data is 0.782064
# accuracy based on training data is 0.787367
# accuracy based on training data is 0.789537
# accuracy based on training data is 0.784716
# accuracy based on training data is 0.788573
# accuracy based on training data is 0.792430
# accuracy based on training data is 0.789778
# accuracy based on training data is 0.790984
# accuracy based on training data is 0.793877
# accuracy based on training data is 0.782546
# accuracy based on training data is 0.785680
# accuracy based on training data is 0.785921
# accuracy based on training data is 0.791948
# accuracy based on training data is 0.794359
# accuracy based on training data is 0.788332
# accuracy based on training data is 0.788814
# accuracy based on training data is 0.790019
# accuracy based on training data is 0.792912
# accuracy based on training data is 0.798216
# accuracy based on training data is 0.786162
# accuracy based on training data is 0.777483
# accuracy based on training data is 0.787126
# accuracy based on training data is 0.778689
# accuracy based on training data is 0.784233
# accuracy based on training data is 0.781340
# accuracy based on training data is 0.792189
# accuracy based on training data is 0.783751
# accuracy based on training data is 0.786644
# accuracy based on training data is 0.787608
# accuracy based on training data is 0.787367
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.788332
# accuracy based on training data is 0.786885
# accuracy based on training data is 0.803520
# accuracy based on training data is 0.790743
# accuracy based on training data is 0.783269
# accuracy based on training data is 0.791707
# accuracy based on training data is 0.794600
# accuracy based on training data is 0.793635
# accuracy based on training data is 0.800868
# accuracy based on training data is 0.801109
# accuracy based on training data is 0.795564
# accuracy based on training data is 0.797975
# accuracy based on training data is 0.800386
# accuracy based on training data is 0.792430
# accuracy based on training data is 0.792671
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.799180
# accuracy based on training data is 0.798698
# accuracy based on training data is 0.775072
# accuracy based on training data is 0.779653
# accuracy based on training data is 0.778447
# accuracy based on training data is 0.777001
# accuracy based on training data is 0.778447
# accuracy based on training data is 0.784716
# accuracy based on training data is 0.782305
# accuracy based on training data is 0.784957
# accuracy based on training data is 0.790260
# accuracy based on training data is 0.783510
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.784233
# accuracy based on training data is 0.788332
# accuracy based on training data is 0.784474
# accuracy based on training data is 0.781581
# accuracy based on training data is 0.786403
# accuracy based on training data is 0.785439
# accuracy based on training data is 0.782064
# accuracy based on training data is 0.783751
# accuracy based on training data is 0.790984
# accuracy based on training data is 0.787608
# accuracy based on training data is 0.761331
# accuracy based on training data is 0.773144
# accuracy based on training data is 0.784716
# accuracy based on training data is 0.775313
# accuracy based on training data is 0.777483
# accuracy based on training data is 0.786403
# accuracy based on training data is 0.787608
# accuracy based on training data is 0.788332
# accuracy based on training data is 0.787126
# accuracy based on training data is 0.795564
# accuracy based on training data is 0.791707
# accuracy based on training data is 0.784957
# accuracy based on training data is 0.770974
# accuracy based on training data is 0.790501
# accuracy based on training data is 0.784474
# accuracy based on training data is 0.791466
# accuracy based on training data is 0.794841
# accuracy based on training data is 0.793635
# accuracy based on training data is 0.802314
# accuracy based on training data is 0.801109
# accuracy based on training data is 0.794841
# accuracy based on training data is 0.797975
# accuracy based on training data is 0.799904
# accuracy based on training data is 0.792912
# accuracy based on training data is 0.792430
# accuracy based on training data is 0.788814
# accuracy based on training data is 0.798457
# accuracy based on training data is 0.798939
# accuracy based on training data is 0.789296
# accuracy based on training data is 0.788091
# accuracy based on training data is 0.792671
# accuracy based on training data is 0.784474
# accuracy based on training data is 0.797493
# accuracy based on training data is 0.794359
# accuracy based on training data is 0.799180
# accuracy based on training data is 0.796046
# accuracy based on training data is 0.799662
# accuracy based on training data is 0.802073
# accuracy based on training data is 0.803761
# accuracy based on training data is 0.802555
# accuracy based on training data is 0.782787
# accuracy based on training data is 0.789055
# accuracy based on training data is 0.787367
# accuracy based on training data is 0.786644
# accuracy based on training data is 0.795805
# accuracy based on training data is 0.789778
# accuracy based on training data is 0.784474
# accuracy based on training data is 0.779412
# accuracy based on training data is 0.790019
# accuracy based on training data is 0.798939
# accuracy based on training data is 0.796046
# accuracy based on training data is 0.801109
# accuracy based on training data is 0.802314
# accuracy based on training data is 0.804243
# accuracy based on training data is 0.803038
# accuracy based on training data is 0.795082
# accuracy based on training data is 0.805931
# accuracy based on training data is 0.790260
# accuracy based on training data is 0.805448
# best features are: 'time', 'timeofweek', 'stepsfeature_index671', 'stepsfeature_index672', 'stepsfeature_index1343', 'heartfeature_index671', 'heartfeature_index672', 'heartfeature_index1343'
# accuracy based on training data is 0.805931

# %%
# Out:
# prediction score on test data is 0.589200
# false positive rate is 0.207329
# false negative rate is 0.203472

# %%
from lib.newMachineLearningModels import *

# %%
ndata1_ac_shr_model, ndata1_ac_shr_model_features = get_selected_model(ndata1_ac_shr_train, 
                                                                       ndata1_ac_shr_features[2:], 
                                                                       'inactive', 'Random Forest', optimized=False)
ndata1_ac_shr_model_predicted, ndata1_ac_shr_model_accuracy = get_prediction(ndata1_ac_shr_test, 
                                                                             ndata1_ac_shr_model, 
                                                                             'inactive', 
                                                                             ndata1_ac_shr_model_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-b52a5a11526e> in <module>()
#       1 ndata1_ac_shr_model, ndata1_ac_shr_model_features = get_selected_model(ndata1_ac_shr_train,
#       2                                                                        ndata1_ac_shr_features[2:],
# ----> 3                                                                        'inactive', 'Random Forest', optimized=False)
#       4 ndata1_ac_shr_model_predicted, ndata1_ac_shr_model_accuracy = get_prediction(ndata1_ac_shr_test,
#       5                                                                              ndata1_ac_shr_model,
#
# /Users/ywang/Desktop/projectMUB/lib/newMachineLearningModels.py in get_selected_model(data, feature, target, model_method, optimized)
#     121         return True
#     122     else:
# --> 123         print('current model does not meet accuracy threshold, therefore rejected.')
#     124         return False
#     125
#
# /Users/ywang/Desktop/projectMUB/lib/newMachineLearningModels.py in get_model(data, feature, target, model_method, optimized)
#     108 def get_prediction(data, model, target, feature):
#     109     print(feature)
# --> 110     x_predict = data[feature]
#     111     y_predicted = model.predict(x_predict)
#     112     # data.loc[:, 'predicted'] = y_predicted
#
# ValueError: too many values to unpack (expected 2)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-7692f559fa49> in <module>()
# ----> 1 ndata1_ac_shr_features[0,1,4,5,6,7,8]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
ndata1_ac_shr_model_predicted, ndata1_ac_shr_model_accuracy = get_prediction(ndata1_ac_shr_test, 
                                                                             ndata1_ac_shr_model, 
                                                                             'inactive', 
                                                                             ndata1_ac_shr_features)
# Out:
# ['time', 'dayofweek', 'timeofweek', 'stepsfeature_index671', 'stepsfeature_index672', 'stepsfeature_index1343', 'heartfeature_index671', 'heartfeature_index672', 'heartfeature_index1343']
# prediction accuracy based on test data is 0.615236

# %%
ndata1_cr_model, ndata1_cr_model_features = get_dt_model(ndata1_cr, ndata1_cr_features, 'inactive', optimized=True)
ndata1_ac_s_model, ndata1_ac_s_model_features = get_dt_model(ndata1_ac_s, ndata1_ac_s_features, 
                                                             'inactive', optimized=True)
ndata1_ac_sh_model, ndata1_ac_sh_model_features = get_dt_model(ndata1_ac_sh, ndata1_ac_sh_features, 
                                                               'inactive', optimized=True)
# Out:
# accuracy based on training data is 0.652727
# accuracy based on training data is 0.551011
# accuracy based on training data is 0.696844
# accuracy based on training data is 0.694547
# accuracy based on training data is 0.696538
# accuracy based on training data is 0.696844
# accuracy based on training data is 0.696538
# best features are: 'timeofweek'
# accuracy based on training data is 0.696844
# accuracy based on training data is 0.629894
# accuracy based on training data is 0.629894
# accuracy based on training data is 0.630665
# accuracy based on training data is 0.672710
# accuracy based on training data is 0.686789
# accuracy based on training data is 0.692960
# accuracy based on training data is 0.716297
# best features are: 'stepsfeature_index671', 'stepsfeature_index672', 'stepsfeature_index1343'
# accuracy based on training data is 0.716297
# accuracy based on training data is 0.629894
# accuracy based on training data is 0.629894
# accuracy based on training data is 0.630665
# accuracy based on training data is 0.628737
# accuracy based on training data is 0.632787
# accuracy based on training data is 0.632015
# accuracy based on training data is 0.672517
# accuracy based on training data is 0.687753
# accuracy based on training data is 0.673095
# accuracy based on training data is 0.682546
# accuracy based on training data is 0.696432
# accuracy based on training data is 0.692960
# accuracy based on training data is 0.679074
# accuracy based on training data is 0.672710
# accuracy based on training data is 0.692382
# accuracy based on training data is 0.699325
# accuracy based on training data is 0.700289
# accuracy based on training data is 0.686017
# accuracy based on training data is 0.683703
# accuracy based on training data is 0.709932
# accuracy based on training data is 0.712633
# accuracy based on training data is 0.716104
# accuracy based on training data is 0.707425
# accuracy based on training data is 0.711861
# accuracy based on training data is 0.732112
# accuracy based on training data is 0.723819
# accuracy based on training data is 0.725747
# accuracy based on training data is 0.730376
# accuracy based on training data is 0.712247
# accuracy based on training data is 0.731148
# accuracy based on training data is 0.740212
# accuracy based on training data is 0.723240
# accuracy based on training data is 0.722276
# accuracy based on training data is 0.730376
# accuracy based on training data is 0.716297
# accuracy based on training data is 0.735391
# accuracy based on training data is 0.733076
# accuracy based on training data is 0.734426
# accuracy based on training data is 0.737319
# accuracy based on training data is 0.738476
# accuracy based on training data is 0.741948
# accuracy based on training data is 0.748505
# accuracy based on training data is 0.746770
# accuracy based on training data is 0.745419
# accuracy based on training data is 0.733655
# accuracy based on training data is 0.752748
# accuracy based on training data is 0.747541
# accuracy based on training data is 0.751591
# accuracy based on training data is 0.753134
# accuracy based on training data is 0.761427
# accuracy based on training data is 0.756606
# accuracy based on training data is 0.753327
# accuracy based on training data is 0.755063
# accuracy based on training data is 0.756220
# accuracy based on training data is 0.752555
# accuracy based on training data is 0.753905
# accuracy based on training data is 0.761813
# accuracy based on training data is 0.763742
# accuracy based on training data is 0.763742
# accuracy based on training data is 0.765863
# accuracy based on training data is 0.766635
# accuracy based on training data is 0.765092
# accuracy based on training data is 0.773963
# best features are: 'stepsfeature_index671', 'stepsfeature_index672', 'stepsfeature_index1343', 'heartfeature_index671', 'heartfeature_index672', 'heartfeature_index1343'
# accuracy based on training data is 0.773963

# %%
ndata1_ac_model, ndata1_ac_model_features = get_dt_model(ndata1_ac, ndata1_ac_features, 'inactive', optimized=True)

# %% [markdown]
# frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'), index=['Utah', 'Ohio', 'Texas', 'Oregon']); frame
# foo = set(['a', 'b','b', 'c', 'd', 'e'])
# print(random.sample(foo,2))
# type(set([x for x in range(7)])[0])
# frame.reset_index(inplace=True)
# frame.loc[[2,3], :]
